# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ejercicio 1
#
# Exercise 1
#
# Let's say, in my office, it takes me 10 seconds (time) to travel 25 meters (distance) to the coffee machine. If we want to express the above situation as a function, then it would be:
#
# distance = speed * time
#
# So for this case, speed is the first derivative of the distance function above. As speed describes the rate of change of distance over time, when people say taking the first derivative of a certain function, they mean finding out the rate of change of a function.
#
# Find the speed and build the linear function on distance $d$
# over time $t$
# , when $t /in[0,10]$
# .

# %%
def distance(speed:float, time:float)->float:
  return speed * time
t = np.linspace(0, 10, 1000)
speed = 25/10 #esto es 25 metros entre 10 segundos, porque unidades de la velocidad es distancias sobre tiempo
plt.plot(t, distance(speed, t)) #speed es una constante y t es la variable, tiene forma lineal del tipo k*x (velocidad * distancia)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 2:
# It turned out that I wasn't walking a constant speed towards getting my coffee, but I was accelerating (my speed increased over time). If my initial *speed = 0*, it still took me 10 seconds to travel from my seat to my coffee, but I was walking faster and faster.$V_o$ = initial speed = $0$  $t = time$   $a = acceleration$ **distance** = $V_o * t + 0.5 * a * (t^2)$ **speed** = $V_o + a * t$ The first derivative of the speed function is acceleration. I realize that the speed funct

# %%
# distance = v0 + t+0.5 a*(t*t)
def distance(v_0:float, a:float, t:float)->float:
  return v_0 * t + 0.5 * a * t * t

def speed(v_0:float, a:float, t:float)->float:
  return v_0 + a * t

t = np.linspace(0, 10, 1000)
v_0 = 0
# a = 25 meters -> la distancia es 25 = o*10 + 0.5 * a * 10 * 10 -> 25 =50*a
a = 0.5
plt.plot(t, speed(v_0, a, t))
plt.grid(True)
plt.show()

# %%
plt.plot(t, distance(v_0, a, t))
plt.grid(True)
plt.show()

# %% [markdown]
# ##Exercise 3
# When I arrive to the coffee machine, I hear my colleague talking about the per-unit costs of producing 'product B' for the company. As the company produces more units, the per-unit costs continue to decrease until a point where they start to increase.
#
# To optimize the per-unit production cost at its minimum to optimize efficiency, the company would need to find the number of units to be produced where the per-unit production costs begin to change from decreasing to increasing.
#
# Build a quadratic function f(x)=0.1x
# 2
#  −9x+4500 on x∈[0,100] to create the per-unit cost function, and make a conclusion.

# %%
import numpy as np
def cost_per_unit(x):
  return 0.1*x**2 -9*x+4500
units_produced = np.arange(0, 101)
costs = cost_per_unit(units_produced)

# %%
min_cost = np.min(costs)

optimal_units_index = np.argmin(costs)
optimal_units = units_produced[optimal_units_index]

print(f'El costo mínimo por unidad es: {min_cost}')
print(f'Se alcanza con la producción de: {optimal_units} unidades.')
# Out:
# El costo mínimo por unidad es: 4297.5
# Se alcanza con la producción de: 45 unidades.

# %% [markdown]
# Linear Algebra
# Exercise 1: Sum of two matrices
#
# Suppose we have two matrices A and B.
#
# A = [[1,2],[3,4]]
# B = [[4,5],[6,7]]
#
# then we get
# A+B = [[5,7],[9,11]]
# A-B = [[-3,-3],[-3,-3]]
#
# Make the sum of two matrices using Python with NumPy

# %%
# Creating first matrix

A = np.array([[1, 2], [3, 4]])

# Creating second matrix

B = np.array([[4 , 5], [6, 7]])

# Print elements

print(A)
print(B)

# Adding both matrices

sum_matrices = A + B
print(sum_matrices)

resta_matrices = A - B
print(resta_matrices)
# Out:
# [[1 2]
#  [3 4]]
# [[4 5]
#  [6 7]]
# [[ 5  7]
#  [ 9 11]]
# [[-3 -3]
#  [-3 -3]]

# %% [markdown]
# Exercise 2: Sum of two lists
#
# There will be many situations in which we'll have to find an index-wise summation of two different lists. This can have possible applications in day-to-day programming. In this exercise, we will solve the same problem in various ways in which this task can be performed.
#
# We have the following two lists:
#
# list1 = [2, 5, 4, 7, 3]
# list2 = [1, 4, 6, 9, 10]
#
# Now let's use Python code to demonstrate addition of two lists.

# %%
# Naive method

# Initializing lists
list1 = [2, 5, 4, 7, 3]
list2 = [1, 4, 6, 9, 10]

# Printing original lists
print ("Original list 1 : " + str(list1))
print ("Original list 2 : " + str(list2))

# Using naive method to add two lists
res_list = []
for i in range(0, len(list1)):
    res_list.append(list1[i] + list2[i])

# Printing resulting list
print ("Resulting list is : " + str(res_list))
# Out:
# Original list 1 : [2, 5, 4, 7, 3]
# Original list 2 : [1, 4, 6, 9, 10]
# Resulting list is : [3, 9, 10, 16, 13]

# %%
# Use list comprehension to perform addition of the two lists:

# Initializing lists

list1 = [2, 5, 4, 7, 3]
list2 = [1, 4, 6, 9, 10]

# Printing original lists

print("Lista original 1 : " + str(list1))
print("Lista original 2 : " + str(list2))

# Using list comprehension to add two lists

res_list = [list1[i] + list2[i] for i in range(len(list1))]

# Printing resulting list
print("Lista resultante es : " + str(res_list))
# Out:
# Lista original 1 : [2, 5, 4, 7, 3]
# Lista original 2 : [1, 4, 6, 9, 10]
# Lista resultante es : [3, 9, 10, 16, 13]

# %%
# Use map() + add():
import operator

# Initializing lists
list1 = [2, 5, 4, 7, 3]
list2 = [1, 4, 6, 9, 10]

# Printing original lists
print("Lista original 1 : " + str(list1))
print("Lista original 2 : " + str(list2))

# Using map() + add() to add two lists
res_list = list(map(operator.add, list1, list2))

# Printing resulting list
print("Lista resultante es : " + str(res_list))
# Out:
# Lista original 1 : [2, 5, 4, 7, 3]
# Lista original 2 : [1, 4, 6, 9, 10]
# Lista resultante es : [3, 9, 10, 16, 13]

# %%
# Use zip() + sum():

# Initializing lists
list1 = [2, 5, 4, 7, 3]
list2 = [1, 4, 6, 9, 10]

# Printing original lists
print("Lista original 1 : " + str(list1))
print("Lista original 2 : " + str(list2))

# Using zip() + sum() to add two lists
res_list = [x + y for x, y in zip(list1, list2)]

# Printing resulting list
print("Lista resultante es : " + str(res_list))
# Out:
# Lista original 1 : [2, 5, 4, 7, 3]
# Lista original 2 : [1, 4, 6, 9, 10]
# Lista resultante es : [3, 9, 10, 16, 13]

# %% [markdown]
# Exercise 3: Dot multiplication
#
# We have two matrices:
#
# matrix1 = [[1,7,3],
#  [4,5,2],
#  [3,6,1]]
# matrix2 = [[5,4,1],
#  [1,2,3],
#  [4,5,2]]
#
# A simple technique but expensive method for larger input datasets is using for loops. In this exercise, we will first use nested for loops to iterate through each row and column of the matrices, and then we will perform the same multiplication using NumPy.

# %%
# Using a for loop input two matrices of size n x m
matrix1 = [[1,7,3],
 [4,5,2],
 [3,6,1]]
matrix2 = [[5,4,1],
 [1,2,3],
 [4,5,2]]

res = [[0 for x in range(3)] for y in range(3)]

# Explicit for loops
for i in range(len(matrix1)):
    for j in range(len(matrix2[0])):
        for k in range(len(matrix2)):

            # Resulting matrix
            res[i][j] += matrix1[i][k] * matrix2[k][j]

print(res)
# Out:
# [[24, 33, 28], [33, 36, 23], [25, 29, 23]]

# %%
# Import libraries
import numpy as np

# Input two matrices
matrix1_np = np.array([[1, 7, 3],
                       [4, 5, 2],
                       [3, 6, 1]])
matrix2_np = np.array([[5, 4, 1],
                       [1, 2, 3],
                       [4, 5, 2]])

# This will return dot product
res_np = np.dot(matrix1_np, matrix2_np)

# Print resulting matrix
print("Resultado usando NumPy:")
print(res_np)
# Out:
# Resultado usando NumPy:
# [[24 33 28]
#  [33 36 23]
#  [25 29 23]]
